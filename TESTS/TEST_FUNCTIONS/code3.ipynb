# %%
# inline_code.py

import os
import time

print("Démarrage du script")
for i in range(3):
    print(f"Étape {i+1}")
    time.sleep(1)
print("Fin du script")

# %%
import pandas as pd

df = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
print(df)

# %%
def greet(name):
    return f"Bonjour, {name}!"
print(greet("Alice"))

def add(a, b):
    return a + b
print(f"La somme de 3 et 5 est {add(3, 5)}")
