# %%
import pandas as pd
import numpy as np

def count_lines(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return sum(1 for line in f)
    return i



def create_dataframe(list_letters, list_numbers=None):
    data = {'Letters': list_letters}
    if list_numbers is not None:
        data['Numbers'] = list_numbers
    df = pd.DataFrame(data)
    return df
